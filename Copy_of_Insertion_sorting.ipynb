# %% [markdown]
# <a href="https://colab.research.google.com/github/Teja3993/my-first-repo/blob/main/Copy_of_Insertion_sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implementing Insertion sorting

def insertion_sort(arr):
  for i in range(1,len(arr)):
    key = arr[i]
    j = i-1
    while j>=0 and arr[j]>key:
      arr[j+1] = arr[j]
      j=j-1
      arr[j+1]=key

  return arr


print(insertion_sort([21,55,1,19,2,465,72,0,88]))



#Implementing stacks

test_arr = [10]
n = len(test_arr)

def push_element(val,a,n,top):
  if top == n:
    print("No space")
  else:
    a[top]=val
    top = top+1
  return a

def pop_element(a,top):
  if top == -1:
    print("No element to remove")
  else:
    print(a[top])
    top=top-1

  return a


def display_element(a,top):
  for i in range(0,top):
    print(a[i])
# Out:
# [0, 1, 2, 19, 21, 55, 72, 88, 465]

# %%
def push(stack,item):
  if len(stack) == n:
    print("Stack is full")
  else:
    stack.append(item)
    print("pushed item on stack is ",item)

def pop_element(stack):
  if len(stack) == 0:
    return "stack is empty"
  return stack.pop()

def display_stack(stack):
  if len(stack) == 0:
    print("Stack is empty")
  else:
    for i in stack:
      print(i)


n = 4
stack = [1,2]
push(stack,40)
push(stack,70)
push(stack,50)
pop_element(stack)
display_stack(stack)
# Out:
# pushed item on stack is  40
# pushed item on stack is  70
# Stack is full
# 1
# 2
# 40

# %%
n =3
top =-1
stack = [None]*n
def push(item):
  global top
  if top >= n-1:
    print("Stack is full")
  else:
    top = top+1
    stack[top] = item
    print("pushed item is ",item)

def pop_element():
  global top
  if top == -1:
    return "Stack is empty"
  else:
    item=stack[top]
    print("Popped item is ",item)
    top = top-1

def display_stack():
  global top
  if top == -1:
    print("Stack is empty")
  else:
    for i in range(top,-1,-1):
      print(stack[i])

display_stack()
push(10)
push(20)
push(30)
push(40)
display_stack()
pop_element()
display_stack()
pop_element()
pop_element()
pop_element()
# Out:
# Stack is empty
# pushed item is  10
# pushed item is  20
# pushed item is  30
# Stack is full
# 30
# 20
# 10
# Popped item is  30
# 20
# 10
# Popped item is  20
# Popped item is  10
# 'Stack is empty'
